# %% [markdown]
# # Making reactions file
# DO 12-6-2018
# Setting up all of the C. therm reactions in a way that eQuilibrator can read
#
# DO 1-15-2019
# Adding some cofactor balancing reactions

# %%
import numpy as np
import pandas as pd
from equilibrator_api import Reaction, ComponentContribution, ReactionMatcher, CompoundMatcher, ParseError, Pathway
from equilibrator_api.bounds import Bounds
# %matplotlib inline

# %%
rxnDf = pd.read_excel('list of reactions v2.xlsx', sheet_name = 'plaintext')
rxnDf[:5]
# Out:
#    Name                                    ReactionFormula  KEGG IDs  \
# 0  CBtx                     H2O + ATP <=> ADP + Phosphate        NaN
# 1   CBP  Phosphate + Cellobiose <=> D-Glucose + Glucose...       NaN
# 2   GLK    D-Glucose + GTP <=> D-Glucose-6-phosphate + GDP       NaN
# 3  PGMT     Glucose-1-phosphate <=> D-glucose-6-phosphate        NaN
# 4   PGI   D-Glucose-6-phosphate <=> D-Fructose-6-phosphate       NaN
#
#    RelativeFlux                                    Notes
# 0           1.0  ATP hydrolysis for cellobiose transport
# 1           1.0                                      NaN
# 2           2.0                                      NaN
# 3           2.0                                      NaN
# 4           2.0                                      NaN

# %%
# make a dictionary to translate KEGG IDs into human-readable abbreviations
keggTranslatorDf = pd.read_excel('KEGG_SEED_DO.xls')
kt = keggTranslatorDf #short name for easier typing

# translate KEGG ID to long name
ktn = kt.loc[:,['KEGG ID(S)', 'PRIMARY NAME']]
ktn['KEGG ID(S)'] = ktn['KEGG ID(S)'].str.lower() # set to lower case for better matching
ktn.set_index('KEGG ID(S)', inplace = True)

# translate long name to KEGG ID
# the original dictionaries sometimes had trouble with duplicate KEGG IDs. If there are duplicates, make sure to choose the lowest number
ntk = kt.loc[:,['PRIMARY NAME', 'KEGG ID(S)']].sort_values(by = ['KEGG ID(S)'], ascending = True)
ntk['PRIMARY NAME'] = ntk['PRIMARY NAME'].str.lower() # set to lower case for better matching
ntk = ntk.groupby('PRIMARY NAME').first() # take the first KEGG ID in each group

# translate KEGG ID to abbreviation
kta = kt.loc[:,['KEGG ID(S)', 'ABBREVIATION']]
kta['KEGG ID(S)'] = kta['KEGG ID(S)'].str.lower() # set to lower case for better matching
kta.set_index('KEGG ID(S)', inplace = True)

# %%
def translateKeggString(keggStr, k2n):
    """
    Translate a reaction written with KEGG IDs to one written with
    plaintext abbreviations for each metabolite
    
    Args:
       keggStr: a reaction written with KEGG IDs
       kt: a dictionary for translating from KEGG to names or the reverse
    """
    newStr = '' # empty string to hold the result
    for word in keggStr.split():
        try:
            newName = k2n.loc[word.lower()]
        except:
            newName = word     
        newStr += newName # add the translated word to the string
        newStr += ' ' # add a space
    #print(newStr) # for debugging
    return(newStr)

# %%
# translate the KEGG formulas to plaintext formulas
rxnDf['formula'] = rxnDf['ReactionFormula'].apply(lambda x: translateKeggString(x, ntk))
rxnDf['form_short'] = rxnDf['formula'].apply(lambda x: translateKeggString(x, kta))
rxnDf
# Out:
#           Name                                    ReactionFormula  KEGG IDs  \
# 0         CBtx                     H2O + ATP <=> ADP + Phosphate        NaN
# 1          CBP  Phosphate + Cellobiose <=> D-Glucose + Glucose...       NaN
# 2          GLK    D-Glucose + GTP <=> D-Glucose-6-phosphate + GDP       NaN
# 3         PGMT     Glucose-1-phosphate <=> D-glucose-6-phosphate        NaN
# 4          PGI   D-Glucose-6-phosphate <=> D-Fructose-6-phosphate       NaN
# 5      PFK-PPi  PPi + D-fructose-6-phosphate <=> Phosphate + D...       NaN
# 6      PFK-ATP  ATP + D-Fructose-6-phosphate <=> ADP + D-Fruct...       NaN
# 7          FBA  D-Fructose-1,6-bisphosphate <=> Glycerone-phos...       NaN
# 8          TPI  Glycerone-phosphate <=> D-Glyceraldehyde3-phos...       NaN
# 9        GAPDH  Phosphate + NAD + D-Glyceraldehyde3-phosphate ...       NaN
# 10        GAPN  D-Glyceraldehyde3-phosphate + NADP  + H2O <=> ...       NaN
# 11     PGK-ATP  ADP + 1,3-Bisphosphoglycerate <=> ATP + D-Glyc...       NaN
# 12     PGK-GTP  GDP + 1,3-Bisphosphoglycerate <=> GTP + D-Glyc...       NaN
# 13         PGM  D-Glycerate-3-phosphate <=> D-Glycerate-2-phos...       NaN
# 14         ENO  D-Glycerate-2-phosphate <=> Phosphoenolpyruvat...       NaN
# 15         PYK       ADP + Phosphoenolpyruvate <=> Pyruvate + ATP       NaN
# 16        PPDK  AMP + PPi + Phosphoenolpyruvate <=> ATP + Phos...       NaN
# 17       PEPCK  GDP + CO2 + Phosphoenolpyruvate <=> GTP + Oxal...       NaN
# 18         MDH             NADH + Oxaloacetate <=> NAD + L-Malate       NaN
# 19          ME        NADP  + L-Malate <=> NADPH + CO2 + Pyruvate       NaN
# 20        PFOR  CoA + 2 Ferredoxin(ox) + Pyruvate <=> H+ + Ace...       NaN
# 21  RNF_ATPase  2 Ferredoxin(red) + 1 NAD + 1.25 H+ + 0.25 ADP...       NaN
# 22  RNF_PPiase  2 Ferredoxin(red) + 1 NAD + 1.5 H+ + 1 Phospha...       NaN
# 23         NFN  2 ferredoxin(red) + NADH + 2 NADP = 2 ferredox...       NaN
# 24         PDC                    Pyruvate <=> Acetaldehyde + CO2       NaN
# 25   ALDH-NADH     NADH + Acetyl-CoA <=> NAD + CoA + Acetaldehyde       NaN
# 26  ALDH-NADPH   NADPH + Acetyl-CoA <=> NADP + CoA + Acetaldehyde       NaN
# 27    ADH-NADH              Acetaldehyde + NADH <=> Ethanol + NAD       NaN
# 28   ADH-NADPH            Acetaldehyde + NADPH <=> Ethanol + NADP       NaN
# 29   Bifur_Hyd  2 ferredoxin(red) + NADH + 2 H+ = NAD + 2 H2 +...       NaN
# 30         NDK                            GTP + ADP <=> ATP + GDP       NaN
# 31     Gly-cyc                      ATP + Phosphate <=> ADP + PPi       NaN
# 32  NADPH-FNOR  2 Ferredoxin(red) + NADP <=> 2 Ferredoxin(ox) ...       NaN
# 33   NADH-FNOR  2 Ferredoxin(red) + NAD <=> 2 Ferredoxin(ox) +...       NaN
# 34         ADK                                ATP + AMP <=> 2 ADP       NaN
#
#     RelativeFlux                                    Notes  \
# 0            1.0  ATP hydrolysis for cellobiose transport
# 1            1.0                                      NaN
# 2            2.0                                      NaN
# 3            2.0                                      NaN
# 4            2.0                                      NaN
# 5            2.0                                      NaN
# 6            2.0                                      NaN
# 7            2.0                                      NaN
# 8            4.0                                      NaN
# 9            4.0                                      NaN
# 10           4.0         Replaces GAPDH and PGK reactions
# 11           4.0                                      NaN
# 12           4.0                                      NaN
# 13           4.0                                      NaN
# 14           4.0                                      NaN
# 15           4.0                                      NaN
# 16           4.0                                      NaN
# 17           4.0                                      NaN
# 18           4.0                                      NaN
# 19           4.0                                      NaN
# 20           4.0                                      NaN
# 21           4.0                                      NaN
# 22           4.0                                      NaN
# 23           4.0                                      NaN
# 24           4.0                                      NaN
# 25           4.0                                      NaN
# 26           4.0                                      NaN
# 27           4.0                                      NaN
# 28           4.0                                      NaN
# 29           0.0                  Bifurcating hydrogenase
# 30           NaN                                      NaN
# 31           NaN                                      NaN
# 32           NaN                                      NaN
# 33           NaN                                      NaN
# 34           NaN                                      NaN
#
#                                               formula  \
# 0                C00001 + C00002 <=> C00008 + C00009
# 1                C00009 + C00185 <=> C00031 + C00103
# 2                C00031 + C00044 <=> C00092 + C00035
# 3                                  C00103 <=> C00092
# 4                                  C00092 <=> C00085
# 5       C00013 + C00085 <=> C00009 + C00354 + C00080
# 6                C00002 + C00085 <=> C00008 + C00354
# 7                         C00354 <=> C00111 + C00118
# 8                                  C00111 <=> C00118
# 9       C00009 + C00003 + C00118 <=> C00004 + C00236
# 10      C00118 + C00006 + C00001 <=> C00197 + C00005
# 11               C00008 + C00236 <=> C00002 + C00197
# 12               C00035 + C00236 <=> C00044 + C00197
# 13                                 C00197 <=> C00631
# 14                        C00631 <=> C00074 + C00001
# 15               C00008 + C00074 <=> C00022 + C00002
# 16  C00020 + C00013 + C00074 <=> C00002 + C00009 +...
# 17      C00035 + C00011 + C00074 <=> C00044 + C00036
# 18               C00004 + C00036 <=> C00003 + C00149
# 19      C00006 + C00149 <=> C00005 + C00011 + C00022
# 20  C00010 + 2 C00139 + C00022 <=> C00080 + C00024...
# 21  2 C00138 + 1 C00003 + 1.25 C00080 + 0.25 C0000...
# 22  2 C00138 + 1 C00003 + 1.5 C00080 + 1 C00009 <=...
# 23  2 C00138 + C00004 + 2 C00006 = 2 C00139 + C000...
# 24                        C00022 <=> C00084 + C00011
# 25      C00004 + C00024 <=> C00003 + C00010 + C00084
# 26      C00005 + C00024 <=> C00006 + C00010 + C00084
# 27               C00084 + C00004 <=> C00469 + C00003
# 28               C00084 + C00005 <=> C00469 + C00006
# 29  2 C00138 + C00004 + 2 C00080 = C00003 + 2 C002...
# 30               C00044 + C00008 <=> C00002 + C00035
# 31               C00002 + C00009 <=> C00008 + C00013
# 32           2 C00138 + C00006 <=> 2 C00139 + C00005
# 33           2 C00138 + C00003 <=> 2 C00139 + C00004
# 34                      C00002 + C00020 <=> 2 C00008
#
#                                            form_short
# 0                             h2o + atp <=> adp + pi
# 1                         pi + cellb <=> glc-D + g1p
# 2                          glc-D + gtp <=> g6p + gdp
# 3                                        g1p <=> g6p
# 4                                        g6p <=> f6p
# 5                         ppi + f6p <=> pi + fdp + h
# 6                            atp + f6p <=> adp + fdp
# 7                                 fdp <=> dhap + g3p
# 8                                       dhap <=> g3p
# 9                    pi + nad + g3p <=> nadh + 13dpg
# 10                  g3p + nadp + h2o <=> 3pg + nadph
# 11                         adp + 13dpg <=> atp + 3pg
# 12                         gdp + 13dpg <=> gtp + 3pg
# 13                                       3pg <=> 2pg
# 14                                 2pg <=> pep + h2o
# 15                           adp + pep <=> pyr + atp
# 16            amp + ppi + pep <=> atp + pi + pyr + h
# 17                     gdp + co2 + pep <=> gtp + oaa
# 18                        nadh + oaa <=> nad + mal-L
# 19                nadp + mal-L <=> nadph + co2 + pyr
# 20  coa + 2 fdxox + pyr <=> h + accoa + 2 fdxrd + ...
# 21  2 fdxrd + 1 nad + 1.25 h + 0.25 adp + 0.25 pi ...
# 22  2 fdxrd + 1 nad + 1.5 h + 1 pi <=> 2 fdxox + 1...
# 23  2 fdxrd + nadh + 2 nadp = 2 fdxox + nad + 2 na...
# 24                               pyr <=> acald + co2
# 25                nadh + accoa <=> nad + coa + acald
# 26              nadph + accoa <=> nadp + coa + acald
# 27                       acald + nadh <=> etoh + nad
# 28                     acald + nadph <=> etoh + nadp
# 29       2 fdxrd + nadh + 2 h = nad + 2 h2 + 2 fdxox
# 30                           gtp + adp <=> atp + gdp
# 31                            atp + pi <=> adp + ppi
# 32                2 fdxrd + nadp <=> 2 fdxox + nadph
# 33                  2 fdxrd + nad <=> 2 fdxox + nadh
# 34                               atp + amp <=> 2 adp

# %%
rxnDf.loc[31, 'form_short']
# Out:
# 'atp + pi <=> adp + ppi '

# %%
# save the output to a file. Be careful about overwriting this file, since there may be manual edits.
rxnDf.to_excel('all_rxns_v5.xlsx')
