# %% [markdown]
# # Analyzing EFMs
# DO 2-4-2019

# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_excel('all_ems_and_ham_dist_DO_SD.xlsx', sheet_name = 'EFM_vt_display', skiprows = 2)
df[:5]
# Out:
#   EFM name  EFM #  'ATPase1'  new ATPase1'  'CBP'  'BGL'  'GLK-GTP'  \
# 0      NaN      1          0             1      1      0          0
# 1      NaN     24          0             1      1      0          0
# 2      NaN     25          0             1      1      0          0
# 3      NaN     26          0             1      1      0          0
# 4      NaN      4          0             1      0      1          0
#
#    'GLK-ATP'  'PGMT'  'PGI'        ...         Ex_CO2  Ex_h2o  Ex_h  Ex_pi  \
# 0          1       1      2        ...              4      -1     0      0
# 1          1       1      2        ...              4      -1     4      0
# 2          1       1      2        ...              4      -1     4      0
# 3          1       1      2        ...              4      -1     4      0
# 4          2       0      2        ...              4      -1    -1      0
#
#    # EFM reactions (excludes exchange)        MDF  MDF vs wt  ATP gen (Satya)  \
# ...

# %%
df.plot.scatter('MDF', 'ATP gen')

# %%
df.loc[df['MDF'].between(4,6)]
# Out:
#             EFM name  EFM #  'ATPase1'  new ATPase1'  'CBP'  'BGL'  'GLK-GTP'  \
# 46               NaN     97          0             1      1      0          0
# 50               NaN    106          0             1      1      0          0
# 54               NaN     77          4             5      1      0          0
# 58               NaN     75          4             5      1      0          0
# 61               NaN     53          3             4      0      1          0
# 63  Tsac ethanologen     46          3             4      0      1          0
#
#     'GLK-ATP'  'PGMT'  'PGI'        ...         Ex_CO2  Ex_h2o  Ex_h  Ex_pi  \
# 46          1       1      2        ...              4      -1     8      0
# 50          1       1      2        ...              4      -1     8      0
# 54          1       1      2        ...              4      -1     4      0
# 58          1       1      2        ...              4      -1     4      0
# ...
